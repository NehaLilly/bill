# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaLilly/bill/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries (if not already installed)
# !pip install pandas matplotlib scikit-learn statsmodels

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.model_selection import train_test_split

# %%
# Upload file from local machine
from google.colab import files
uploaded = files.upload()

# Load the dataset
data = pd.read_csv('dataset_tk.csv')
# Out:
#      <input type="file" id="files-cf1b63a2-7c93-4b6d-a916-333ab2e1f655" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf1b63a2-7c93-4b6d-a916-333ab2e1f655">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())

# Convert the date column to datetime format (replace 'date_column' with your actual column name)
data['Date'] = pd.to_datetime(data['Date'])

# Set the Date column as the index
data.set_index('Date', inplace=True)

# Check the dataset information
print(data.info())

# Visualize the data
plt.figure(figsize=(12, 6))
plt.plot(data['Power_Consumption'], label='Power Consumption')
plt.title('Power Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Consumption')
plt.legend()
plt.show()
# Out:
#             Unnamed: 0  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand  \
# 0  02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9         40.7
# 1  03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8         39.3
# 2  04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7         38.1
# 3  05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0         39.2
# 4  06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8         39.2
#
#      HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0  30.0  52.5         5.0  ...    70.2        108.2     2.0
# 1  30.1  54.1         4.9  ...    67.9        110.2     1.9
# 2  30.1  53.2         4.8  ...    66.3        106.8     1.7
# 3  30.2  51.5         4.3  ...    65.8        107.0     2.0
# 4  31.0  53.2         4.3  ...    62.9        106.4     2.0
#
#    Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  Tripura
# ...

# %%
# Display the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())

# Print the columns in the dataframe to check if 'Date' exists and with the correct capitalization
print(data.columns)

# Assuming 'date' or similar is the actual column name containing date information
# Change 'date_column_name' to the actual column name from the output above
data['Date'] = pd.to_datetime(data['date_column_name']) # Replace 'date_column_name'

# Set the Date column as the index
data.set_index('Date', inplace=True)

# Check the dataset information
print(data.info())

# Visualize the data
plt.figure(figsize=(12, 6))
plt.plot(data['Power_Consumption'], label='Power Consumption')
plt.title('Power Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Consumption')
plt.legend()
plt.show()

# %%
# Display the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())

# Print the columns in the dataframe to check if 'Date' exists and with the correct capitalization
print(data.columns)

# Assuming 'date' or similar is the actual column name containing date information
# Change 'date_column_name' to the actual column name from the output above
data['Date'] = pd.to_datetime(data['date_column_name']) # Replace 'date_column_name'

# Set the Date column as the index
data.set_index('Date', inplace=True)

# Check the dataset information
print(data.info())

# Visualize the data
plt.figure(figsize=(12, 6))
plt.plot(data['Power_Consumption'], label='Power Consumption')
plt.title('Power Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Consumption')
plt.legend()
plt.show()
# Out:
#             Unnamed: 0  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand  \
# 0  02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9         40.7
# 1  03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8         39.3
# 2  04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7         38.1
# 3  05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0         39.2
# 4  06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8         39.2
#
#      HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0  30.0  52.5         5.0  ...    70.2        108.2     2.0
# 1  30.1  54.1         4.9  ...    67.9        110.2     1.9
# 2  30.1  53.2         4.8  ...    66.3        106.8     1.7
# 3  30.2  51.5         4.3  ...    65.8        107.0     2.0
# 4  31.0  53.2         4.3  ...    62.9        106.4     2.0
#
#    Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  Tripura
# ...

# %%
# Display the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())

# Print the columns in the dataframe to check if 'Date' exists and with the correct capitalization
print(data.columns)

# Assuming 'date' or similar is the actual column name containing date information
# Change 'date_column_name' to the actual column name from the output above
# **Replace 'date_column_name' with the actual column name from the output of data.columns**
data['Date'] = pd.to_datetime(data['Unnamed: 0'])  # Example: Replace 'Unnamed: 0' if that's your date column

# Set the Date column as the index
data.set_index('Date', inplace=True)

# Check the dataset information
print(data.info())

# Visualize the data
plt.figure(figsize=(12, 6))
plt.plot(data['Power_Consumption'], label='Power Consumption')
plt.title('Power Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Consumption')
plt.legend()
plt.show()
# Out:
#             Unnamed: 0  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand  \
# 0  02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9         40.7
# 1  03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8         39.3
# 2  04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7         38.1
# 3  05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0         39.2
# 4  06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8         39.2
#
#      HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0  30.0  52.5         5.0  ...    70.2        108.2     2.0
# 1  30.1  54.1         4.9  ...    67.9        110.2     1.9
# 2  30.1  53.2         4.8  ...    66.3        106.8     1.7
# 3  30.2  51.5         4.3  ...    65.8        107.0     2.0
# 4  31.0  53.2         4.3  ...    62.9        106.4     2.0
#
#    Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  Tripura
# ...

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load the dataset
file_path = '/content/dataset_tk.csv'
data = pd.read_csv(file_path)

# Preprocess the data
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'], format='%d/%m/%Y %H:%M:%S')  # Convert to datetime
data.set_index('Unnamed: 0', inplace=True)  # Set datetime as index

# Select "Punjab" as the target for forecasting
target_state = 'Punjab'
df = data[[target_state]]

# Normalize the data (scaling values between 0 and 1)
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df)

# Prepare data for the LSTM model
def create_sequences(data, time_steps=30):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 30  # Look back 30 time steps (e.g., 30 days)
X, y = create_sequences(df_scaled, time_steps)

# Split data into training and testing sets
split_ratio = 0.8
train_size = int(len(X) * split_ratio)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_steps, 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Training Loss: {train_loss}")
print(f"Testing Loss: {test_loss}")

# Make predictions
predicted = model.predict(X_test)
predicted_unscaled = scaler.inverse_transform(predicted)
y_test_unscaled = scaler.inverse_transform(y_test)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_unscaled, label='Actual Energy Demand')
plt.plot(predicted_unscaled, label='Predicted Energy Demand')
plt.legend()
plt.xlabel('Time Steps')
plt.ylabel(f'{target_state} Energy Demand')
plt.title(f'Actual vs Predicted Energy Demand for {target_state}')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0846 - val_loss: 0.0772
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0542 - val_loss: 0.0743
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0494 - val_loss: 0.0721
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0497 - val_loss: 0.0688
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0489 - val_loss: 0.0671
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0439 - val_loss: 0.0634
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0374 - val_loss: 0.0598
# Epoch 8/20
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

# Calculate MAE, MSE, and RMSE
mae = mean_absolute_error(y_test_unscaled, predicted_unscaled)
mse = mean_squared_error(y_test_unscaled, predicted_unscaled)
rmse = math.sqrt(mse)

# Print the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 27.160621980365953
# Mean Squared Error (MSE): 1602.1453116550156
# Root Mean Squared Error (RMSE): 40.02680741272049

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit

# Load the dataset
file_path = '/content/dataset_tk.csv'
data = pd.read_csv(file_path)

# Preprocess the data
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'], format='%d/%m/%Y %H:%M:%S')  # Convert to datetime
data.set_index('Unnamed: 0', inplace=True)  # Set datetime as index

# Select "Punjab" as the target for forecasting
target_state = 'Punjab'
df = data[[target_state]]

# Normalize the data (scaling values between 0 and 1)
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df)

# Prepare data for the LSTM model
def create_sequences(data, time_steps=30):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 30  # Look back 30 time steps (e.g., 30 days)
X, y = create_sequences(df_scaled, time_steps)

# Split data into training and testing sets
split_ratio = 0.8
train_size = int(len(X) * split_ratio)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Model Architecture (with hyperparameter adjustments and regularization)
model = Sequential()
model.add(Bidirectional(LSTM(100, return_sequences=True, input_shape=(time_steps, 1))))
model.add(Dropout(0.3))  # Dropout for regularization
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(1))

# Compile the model with Adam optimizer and learning rate adjustment
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Early stopping to avoid overfitting and improve training
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping], verbose=1)

# Evaluate the model performance
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Training Loss: {train_loss}")
print(f"Testing Loss: {test_loss}")

# Make predictions
predicted = model.predict(X_test)
predicted_unscaled = scaler.inverse_transform(predicted)
y_test_unscaled = scaler.inverse_transform(y_test)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_unscaled, label='Actual Energy Demand')
plt.plot(predicted_unscaled, label='Predicted Energy Demand')
plt.legend()
plt.xlabel('Time Steps')
plt.ylabel(f'{target_state} Energy Demand')
plt.title(f'Actual vs Predicted Energy Demand for {target_state}')
plt.show()

# Optional: Time Series Cross-Validation (to get an idea of how the model performs across different subsets of the data)
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Rebuild model for each fold
    model = Sequential()
    model.add(Bidirectional(LSTM(100, return_sequences=True, input_shape=(time_steps, 1))))
    model.add(Dropout(0.3))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dropout(0.3))
    model.add(Dense(1))

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=0)
    fold_loss = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold Loss: {fold_loss}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - loss: 0.1160 - val_loss: 0.0731
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0511 - val_loss: 0.0614
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0448 - val_loss: 0.0574
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0403 - val_loss: 0.0500
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0349 - val_loss: 0.0461
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0352 - val_loss: 0.0403
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0292 - val_loss: 0.0363
# Epoch 8/50
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit

# ... (rest of your code remains the same) ...

# Load the dataset
file_path = '/content/dataset_tk.csv'
data = pd.read_csv(file_path)

# Preprocess the data
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'], format='%d/%m/%Y %H:%M:%S')  # Convert to datetime
data.set_index('Unnamed: 0', inplace=True)  # Set datetime as index

# Select "Punjab" as the target for forecasting
target_state = 'Punjab'
df = data[[target_state]]

# Normalize the data (scaling values between 0 and 1)
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df)

# Prepare data for the LSTM model
def create_sequences(data, time_steps=30):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 30  # Look back 30 time steps (e.g., 30 days)
X, y = create_sequences(df_scaled, time_steps)

# Split data into training and testing sets
split_ratio = 0.8
train_size = int(len(X) * split_ratio)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Model Architecture (with hyperparameter adjustments and regularization)
model = Sequential()
model.add(Bidirectional(LSTM(100, return_sequences=True, input_shape=(time_steps, 1))))
model.add(Dropout(0.3))  # Dropout for regularization
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(1))

# Compile the model with Adam optimizer and learning rate adjustment
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Early stopping to avoid overfitting and improve training
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping], verbose=1)

# Evaluate the model performance
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Training Loss: {train_loss}")
print(f"Testing Loss: {test_loss}")

# Make predictions
predicted = model.predict(X_test)
predicted_unscaled = scaler.inverse_transform(predicted)
y_test_unscaled = scaler.inverse_transform(y_test)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_unscaled, label='Actual Energy Demand')
plt.plot(predicted_unscaled, label='Predicted Energy Demand')
plt.legend()
plt.xlabel('Time Steps')
plt.ylabel(f'{target_state} Energy Demand')
plt.title(f'Actual vs Predicted Energy Demand for {target_state}')
plt.show()

# Optional: Time Series Cross-Validation
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Rebuild model for each fold
    model = Sequential()
    model.add(Bidirectional(LSTM(100, return_sequences=True, input_shape=(time_steps, 1))))
    model.add(Dropout(0.3))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dropout(0.3))
    model.add(Dense(1))

    # Create a new optimizer instance for each model
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=0)
    fold_loss = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold Loss: {fold_loss}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - loss: 0.0995 - val_loss: 0.0772
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0554 - val_loss: 0.0633
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0446 - val_loss: 0.0590
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0369 - val_loss: 0.0519
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0360 - val_loss: 0.0486
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0348 - val_loss: 0.0462
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0253 - val_loss: 0.0390
# Epoch 8/50
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit

# Load the dataset
file_path = '/content/dataset_tk.csv'
data = pd.read_csv(file_path)

# Preprocess the data
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'], format='%d/%m/%Y %H:%M:%S')  # Convert to datetime
data.set_index('Unnamed: 0', inplace=True)  # Set datetime as index

# Select "Punjab" as the target for forecasting
target_state = 'Punjab'
df = data[[target_state]]

# Normalize the data (scaling values between 0 and 1)
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df)

# Prepare data for the LSTM model
def create_sequences(data, time_steps=30):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 30  # Look back 30 time steps (e.g., 30 days)
X, y = create_sequences(df_scaled, time_steps)

# Split data into training and testing sets
split_ratio = 0.8
train_size = int(len(X) * split_ratio)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Model Architecture (with hyperparameter adjustments and regularization)
model = Sequential()
model.add(Bidirectional(LSTM(100, return_sequences=True, input_shape=(time_steps, 1))))
model.add(Dropout(0.3))  # Dropout for regularization
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(1))

# Compile the model with Adam optimizer and learning rate adjustment
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Early stopping to avoid overfitting and improve training
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping], verbose=1)

# Evaluate the model performance
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Training Loss: {train_loss}")
print(f"Testing Loss: {test_loss}")

# Make predictions
predicted = model.predict(X_test)
predicted_unscaled = scaler.inverse_transform(predicted)
y_test_unscaled = scaler.inverse_transform(y_test)

# Calculate additional evaluation metrics
mae = mean_absolute_error(y_test_unscaled, predicted_unscaled)
mse = mean_squared_error(y_test_unscaled, predicted_unscaled)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_unscaled, predicted_unscaled)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_unscaled, label='Actual Energy Demand')
plt.plot(predicted_unscaled, label='Predicted Energy Demand')
plt.legend()
plt.xlabel('Time Steps')
plt.ylabel(f'{target_state} Energy Demand')
plt.title(f'Actual vs Predicted Energy Demand for {target_state}')
plt.show()

# Optional: Time Series Cross-Validation
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Rebuild model for each fold
    model = Sequential()
    model.add(Bidirectional(LSTM(100, return_sequences=True, input_shape=(time_steps, 1))))
    model.add(Dropout(0.3))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dropout(0.3))
    model.add(Dense(1))

    # Create a new optimizer instance for each model
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=0)
    fold_loss = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold Loss: {fold_loss}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - loss: 0.0923 - val_loss: 0.0709
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0442 - val_loss: 0.0596
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0392 - val_loss: 0.0563
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0383 - val_loss: 0.0502
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0323 - val_loss: 0.0453
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0356 - val_loss: 0.0417
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0306 - val_loss: 0.0385
# Epoch 8/50
# ...
